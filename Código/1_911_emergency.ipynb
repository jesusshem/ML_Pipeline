# %% [markdown]
# # Importamos librerías

# %%
from __future__ import division
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Cargamos datos

# %%
df_emergency = pd.read_csv('Datasets/911.csv')

# %%
df_emergency.head(15)
# Out:
#           lat        lng                                               desc  \
# 0   40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1   40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2   40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3   40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4   40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
# 5   40.253473 -75.283245  CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...
# 6   40.182111 -75.127795  LAUREL AVE & OAKDALE AVE;  HORSHAM; Station 35...
# 7   40.217286 -75.405182  COLLEGEVILLE RD & LYWISKI RD;  SKIPPACK; Stati...
# 8   40.289027 -75.399590  MAIN ST & OLD SUMNEYTOWN PIKE;  LOWER SALFORD;...
# 9   40.102398 -75.291458  BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD; PLYM...
# 10  40.231990 -75.251891  RT202 PKWY & KNAPP RD; MONTGOMERY; 2015-12-10 ...
# ...

# %%
df_emergency.dtypes
# Out:
# lat          float64
# lng          float64
# desc          object
# zip          float64
# title         object
# timeStamp     object
# twp           object
# addr          object
# e              int64
# dtype: object

# %%
df_emergency.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423909 entries, 0 to 423908
# Data columns (total 9 columns):
# lat          423909 non-null float64
# lng          423909 non-null float64
# desc         423909 non-null object
# zip          371780 non-null float64
# title        423909 non-null object
# timeStamp    423909 non-null object
# twp          423750 non-null object
# addr         423909 non-null object
# e            423909 non-null int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 29.1+ MB

# %% [markdown]
# # Missings

# %% [markdown]
# ## Nota:

# %% [markdown]
# *None* - **str** <br>
# *NaN* - **float**

# %% [markdown]
# ## Nota:

# %% [markdown]
# if (var == 3): <br>
# $\space$ accion 1 <br>
# else: <br>
# $\space$ accion 2

# %%
df_emergency['zip']
# Out:
# 0         19525.0
# 1         19446.0
# 2         19401.0
# 3         19401.0
# 4             NaN
# 5         19446.0
# 6         19044.0
# 7         19426.0
# 8         19438.0
# 9         19462.0
# 10            NaN
# 11        19428.0
# 12        19040.0
# 13        19027.0
# 14            NaN
# 15        18936.0
# 16        19446.0
# 17        19525.0
# 18        19401.0
# 19        18974.0
# 20        19401.0
# 21        19031.0
# 22        19446.0
# 23            NaN
# 24            NaN
# 25        19403.0
# 26        19422.0
# 27        19085.0
# 28            NaN
# 29        18974.0
#            ...
# 423879    19525.0
# 423880    19095.0
# 423881    19002.0
# 423882    19002.0
# 423883    19044.0
# 423884    19440.0
# 423885    18054.0
# 423886    19473.0
# 423887    19403.0
# 423888    19468.0
# 423889    19090.0
# 423890    18074.0
# 423891    19090.0
# 423892    19046.0
# 423893    19446.0
# 423894    19468.0
# 423895    19422.0
# 423896        NaN
# 423897    19090.0
# ...

# %%
df_emergency['zip'].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10         True
# 11        False
# 12        False
# 13        False
# 14         True
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23         True
# 24         True
# 25        False
# 26        False
# 27        False
# 28         True
# 29        False
#           ...
# 423879    False
# 423880    False
# 423881    False
# 423882    False
# 423883    False
# 423884    False
# 423885    False
# 423886    False
# 423887    False
# 423888    False
# 423889    False
# 423890    False
# 423891    False
# 423892    False
# 423893    False
# 423894    False
# 423895    False
# 423896     True
# 423897    False
# 423898    False
# 423899    False
# 423900    False
# 423901    False
# 423902    False
# ...

# %%
df_emergency[df_emergency['zip'].isnull()]
# Out:
#               lat        lng  \
# 4       40.251492 -75.603350
# 10      40.231990 -75.251891
# 14      40.097222 -75.376195
# 23      40.143326 -75.422819
# 24      40.153268 -75.189558
# 28      40.097222 -75.376195
# 30      40.097222 -75.376195
# 34      40.221227 -75.288737
# 37      40.066718 -75.307176
# 42      40.024967 -75.282905
# 48      40.251523 -75.329557
# 49      40.165393 -75.282905
# 54      40.156847 -75.101994
# 70      40.024967 -75.282905
# 119     40.150711 -75.055274
# 140     40.165393 -75.282905
# 156     40.024967 -75.282905
# 169     40.241495 -75.283786
# 174     40.119833 -75.125349
# 175     40.229008 -75.387853
# 180     40.221227 -75.288737
# 181     40.239436 -75.236238
# 188     40.154553 -75.221565
# 189     40.179375 -75.236238
# 190     40.179375 -75.236238
# 201     40.081260 -75.137025
# 209     40.138524 -75.503251
# 211     40.172314 -75.492728
# 214     40.138524 -75.503251
# 221     40.119833 -75.125349
# ...           ...        ...
# ...

# %%
df_emergency['zip'][df_emergency['zip'].isnull()]
# Out:
# 4        NaN
# 10       NaN
# 14       NaN
# 23       NaN
# 24       NaN
# 28       NaN
# 30       NaN
# 34       NaN
# 37       NaN
# 42       NaN
# 48       NaN
# 49       NaN
# 54       NaN
# 70       NaN
# 119      NaN
# 140      NaN
# 156      NaN
# 169      NaN
# 174      NaN
# 175      NaN
# 180      NaN
# 181      NaN
# 188      NaN
# 189      NaN
# 190      NaN
# 201      NaN
# 209      NaN
# 211      NaN
# 214      NaN
# 221      NaN
#           ..
# 423700   NaN
# 423709   NaN
# 423726   NaN
# 423730   NaN
# 423734   NaN
# 423737   NaN
# 423738   NaN
# 423747   NaN
# 423748   NaN
# 423778   NaN
# 423783   NaN
# 423790   NaN
# 423793   NaN
# 423796   NaN
# 423809   NaN
# 423810   NaN
# 423818   NaN
# 423819   NaN
# 423830   NaN
# 423831   NaN
# 423833   NaN
# 423834   NaN
# 423842   NaN
# 423843   NaN
# 423846   NaN
# 423853   NaN
# 423867   NaN
# 423868   NaN
# 423871   NaN
# 423896   NaN
# Name: zip, Length: 52129, dtype: float64

# %%
df_emergency['zip'].isnull().astype(int)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
# 5         0
# 6         0
# 7         0
# 8         0
# 9         0
# 10        1
# 11        0
# 12        0
# 13        0
# 14        1
# 15        0
# 16        0
# 17        0
# 18        0
# 19        0
# 20        0
# 21        0
# 22        0
# 23        1
# 24        1
# 25        0
# 26        0
# 27        0
# 28        1
# 29        0
#          ..
# 423879    0
# 423880    0
# 423881    0
# 423882    0
# 423883    0
# 423884    0
# 423885    0
# 423886    0
# 423887    0
# 423888    0
# 423889    0
# 423890    0
# 423891    0
# 423892    0
# 423893    0
# 423894    0
# 423895    0
# 423896    1
# 423897    0
# 423898    0
# 423899    0
# 423900    0
# 423901    0
# 423902    0
# 423903    0
# 423904    0
# 423905    0
# 423906    0
# 423907    0
# 423908    0
# Name: zip, Length: 423909, dtype: int64

# %% [markdown]
# ## Cuenta todos los elementos de *zip*

# %%
df_emergency['zip'].isnull().count()
# Out:
# 423909

# %% [markdown]
# ## Suma los elementos nullos

# %%
df_emergency['zip'].isnull().sum()
# Out:
# 52129

# %%
df_emergency['zip'].isnull().sum()/len(df_emergency['zip'])
# Out:
# 0.12297214732407191

# %%
type(df_emergency.shape)
# Out:
# tuple

# %%
df_emergency.shape[0]
# Out:
# 423909

# %%
df_emergency['zip'].isnull().sum()/df_emergency.shape[0]
# Out:
# 0.12297214732407191

# %% [markdown]
# # *Lambda* funciones

# %%
f = lambda x, y: x * y - 10

# %%
f(10, 10)
# Out:
# 90

# %%
apply(lambda x, y: x*y - 10, [10, 10])
# Out:
# 90

# %%
map(lambda x, y: x*y - 10, [10, 5], [10, 17])
# Out:
# [90, 75]

# %%
filter(lambda x: x > 0, [10, -10, -13, 10, 0])
# Out:
# [10, 10]
